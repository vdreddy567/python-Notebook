# %% [markdown]
# <a href="https://colab.research.google.com/github/vdreddy567/python-Notebook/blob/main/11_2_residual_networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-rdtyga2e
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-rdtyga2e
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=b4abefad69fb0bfb01159e328fc49cfc1a60a72dbe895737b3124317025f01aa
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w0p87ec5/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    h1 = self.linear1(x)
    h2 = self.linear2(h1.relu()) + h1
    h3 = self.linear3(h2.relu()) + h2
    return self.linear4(h3.relu())

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.568524, train error 60.10,  val loss 1.641260, percent error 65.40
# Epoch     1, train loss 1.274355, train error 47.60,  val loss 1.434862, percent error 57.80
# Epoch     2, train loss 1.072010, train error 38.97,  val loss 1.342203, percent error 51.80
# Epoch     3, train loss 0.904135, train error 32.90,  val loss 1.211401, percent error 46.30
# Epoch     4, train loss 0.824469, train error 29.53,  val loss 1.210747, percent error 45.10
# Epoch     5, train loss 0.706183, train error 25.03,  val loss 1.189135, percent error 43.50
# Epoch     6, train loss 0.610918, train error 21.88,  val loss 1.145177, percent error 42.00
# Epoch     7, train loss 0.516133, train error 17.95,  val loss 1.117127, percent error 40.40
# Epoch     8, train loss 0.474866, train error 16.68,  val loss 1.147577, percent error 41.20
# Epoch     9, train loss 0.382034, train error 13.20,  val loss 1.110647, percent error 37.60
# Epoch    10, train loss 0.371548, train error 13.00,  val loss 1.229354, percent error 39.80
# Epoch    11, train loss 0.289110, train error 9.10,  val loss 1.230747, percent error 39.10
# Epoch    12, train loss 0.212302, train error 6.25,  val loss 1.217833, percent error 38.70
# Epoch    13, train loss 0.201457, train error 6.35,  val loss 1.358210, percent error 39.60
# Epoch    14, train loss 0.186426, train error 5.90,  val loss 1.317100, percent error 36.70
# Epoch    15, train loss 0.150852, train error 4.25,  val loss 1.426678, percent error 39.80
# Epoch    16, train loss 0.163069, train error 4.97,  val loss 1.428082, percent error 39.00
# Epoch    17, train loss 0.127536, train error 3.43,  val loss 1.487899, percent error 39.20
# Epoch    18, train loss 0.099988, train error 2.88,  val loss 1.531511, percent error 38.40
# Epoch    19, train loss 0.061073, train error 1.10,  val loss 1.544720, percent error 37.30
# Epoch    20, train loss 0.024351, train error 0.05,  val loss 1.439731, percent error 37.20
# Epoch    21, train loss 0.016366, train error 0.00,  val loss 1.477842, percent error 36.30
# Epoch    22, train loss 0.013186, train error 0.00,  val loss 1.483117, percent error 36.10
# Epoch    23, train loss 0.011432, train error 0.00,  val loss 1.503744, percent error 36.00
# Epoch    24, train loss 0.010195, train error 0.00,  val loss 1.518262, percent error 36.30
# Epoch    25, train loss 0.009206, train error 0.00,  val loss 1.532215, percent error 36.70
# Epoch    26, train loss 0.008455, train error 0.00,  val loss 1.545141, percent error 36.70
# Epoch    27, train loss 0.007811, train error 0.00,  val loss 1.561588, percent error 36.40
# Epoch    28, train loss 0.007246, train error 0.00,  val loss 1.575223, percent error 36.30
# Epoch    29, train loss 0.006758, train error 0.00,  val loss 1.585622, percent error 36.30
# Epoch    30, train loss 0.006375, train error 0.00,  val loss 1.599547, percent error 36.50
# Epoch    31, train loss 0.005973, train error 0.00,  val loss 1.607571, percent error 36.40
# Epoch    32, train loss 0.005669, train error 0.00,  val loss 1.622084, percent error 36.20
# Epoch    33, train loss 0.005362, train error 0.00,  val loss 1.629568, percent error 36.40
# Epoch    34, train loss 0.005099, train error 0.00,  val loss 1.637766, percent error 36.30
# Epoch    35, train loss 0.004845, train error 0.00,  val loss 1.647425, percent error 36.10
# Epoch    36, train loss 0.004636, train error 0.00,  val loss 1.657487, percent error 36.00
# Epoch    37, train loss 0.004429, train error 0.00,  val loss 1.666832, percent error 36.20
# Epoch    38, train loss 0.004255, train error 0.00,  val loss 1.672261, percent error 36.20
# Epoch    39, train loss 0.004093, train error 0.00,  val loss 1.682066, percent error 35.90
# Epoch    40, train loss 0.003998, train error 0.00,  val loss 1.686369, percent error 36.00
# Epoch    41, train loss 0.003922, train error 0.00,  val loss 1.689412, percent error 36.00
# Epoch    42, train loss 0.003850, train error 0.00,  val loss 1.693546, percent error 36.10
# Epoch    43, train loss 0.003783, train error 0.00,  val loss 1.698112, percent error 36.00
# Epoch    44, train loss 0.003716, train error 0.00,  val loss 1.701496, percent error 36.00
# Epoch    45, train loss 0.003651, train error 0.00,  val loss 1.705590, percent error 36.00
# Epoch    46, train loss 0.003589, train error 0.00,  val loss 1.708522, percent error 36.00
# Epoch    47, train loss 0.003529, train error 0.00,  val loss 1.712693, percent error 36.00
# Epoch    48, train loss 0.003472, train error 0.00,  val loss 1.715017, percent error 36.00
# Epoch    49, train loss 0.003415, train error 0.00,  val loss 1.717559, percent error 36.10
# Epoch    50, train loss 0.003360, train error 0.00,  val loss 1.722095, percent error 36.00
# Epoch    51, train loss 0.003307, train error 0.00,  val loss 1.725609, percent error 35.90
# Epoch    52, train loss 0.003255, train error 0.00,  val loss 1.728634, percent error 36.00
# Epoch    53, train loss 0.003206, train error 0.00,  val loss 1.733173, percent error 35.90
# Epoch    54, train loss 0.003159, train error 0.00,  val loss 1.735453, percent error 35.90
# Epoch    55, train loss 0.003111, train error 0.00,  val loss 1.738709, percent error 36.00
# Epoch    56, train loss 0.003067, train error 0.00,  val loss 1.741642, percent error 35.80
# Epoch    57, train loss 0.003021, train error 0.00,  val loss 1.744025, percent error 35.90
# Epoch    58, train loss 0.002978, train error 0.00,  val loss 1.747905, percent error 35.90
# Epoch    59, train loss 0.002937, train error 0.00,  val loss 1.749805, percent error 36.00
# Epoch    60, train loss 0.002915, train error 0.00,  val loss 1.751660, percent error 35.90
# Epoch    61, train loss 0.002896, train error 0.00,  val loss 1.753703, percent error 35.90
# Epoch    62, train loss 0.002875, train error 0.00,  val loss 1.754853, percent error 35.90
# Epoch    63, train loss 0.002856, train error 0.00,  val loss 1.757034, percent error 36.00
# Epoch    64, train loss 0.002835, train error 0.00,  val loss 1.757711, percent error 36.00
# Epoch    65, train loss 0.002816, train error 0.00,  val loss 1.759680, percent error 35.90
# Epoch    66, train loss 0.002798, train error 0.00,  val loss 1.760880, percent error 35.90
# Epoch    67, train loss 0.002779, train error 0.00,  val loss 1.762453, percent error 36.00
# Epoch    68, train loss 0.002761, train error 0.00,  val loss 1.763672, percent error 36.00
# Epoch    69, train loss 0.002742, train error 0.00,  val loss 1.765082, percent error 36.00
# Epoch    70, train loss 0.002724, train error 0.00,  val loss 1.766773, percent error 36.00
# Epoch    71, train loss 0.002707, train error 0.00,  val loss 1.768121, percent error 36.00
# Epoch    72, train loss 0.002689, train error 0.00,  val loss 1.769310, percent error 36.00
# Epoch    73, train loss 0.002672, train error 0.00,  val loss 1.771250, percent error 36.00
# Epoch    74, train loss 0.002655, train error 0.00,  val loss 1.771981, percent error 36.00
# Epoch    75, train loss 0.002638, train error 0.00,  val loss 1.773344, percent error 36.00
# Epoch    76, train loss 0.002621, train error 0.00,  val loss 1.775138, percent error 36.00
# Epoch    77, train loss 0.002604, train error 0.00,  val loss 1.776300, percent error 36.00
# Epoch    78, train loss 0.002588, train error 0.00,  val loss 1.778034, percent error 36.00
# Epoch    79, train loss 0.002572, train error 0.00,  val loss 1.778830, percent error 36.00
# Epoch    80, train loss 0.002564, train error 0.00,  val loss 1.779381, percent error 36.00
# Epoch    81, train loss 0.002556, train error 0.00,  val loss 1.780334, percent error 36.00
# Epoch    82, train loss 0.002548, train error 0.00,  val loss 1.780979, percent error 36.00
# Epoch    83, train loss 0.002540, train error 0.00,  val loss 1.781785, percent error 35.90
# Epoch    84, train loss 0.002532, train error 0.00,  val loss 1.782291, percent error 36.00
# Epoch    85, train loss 0.002524, train error 0.00,  val loss 1.782881, percent error 35.90
# Epoch    86, train loss 0.002517, train error 0.00,  val loss 1.783823, percent error 35.80
# Epoch    87, train loss 0.002509, train error 0.00,  val loss 1.783950, percent error 35.90
# Epoch    88, train loss 0.002502, train error 0.00,  val loss 1.784803, percent error 35.90
# Epoch    89, train loss 0.002494, train error 0.00,  val loss 1.785596, percent error 35.90
# Epoch    90, train loss 0.002487, train error 0.00,  val loss 1.786106, percent error 35.90
# Epoch    91, train loss 0.002479, train error 0.00,  val loss 1.786590, percent error 35.90
# Epoch    92, train loss 0.002472, train error 0.00,  val loss 1.787421, percent error 35.90
# Epoch    93, train loss 0.002464, train error 0.00,  val loss 1.788259, percent error 35.90
# Epoch    94, train loss 0.002457, train error 0.00,  val loss 1.788920, percent error 35.90
# Epoch    95, train loss 0.002450, train error 0.00,  val loss 1.789720, percent error 35.90
# Epoch    96, train loss 0.002442, train error 0.00,  val loss 1.790188, percent error 35.80
# Epoch    97, train loss 0.002435, train error 0.00,  val loss 1.790617, percent error 35.80
# Epoch    98, train loss 0.002428, train error 0.00,  val loss 1.791302, percent error 35.80
# Epoch    99, train loss 0.002421, train error 0.00,  val loss 1.791727, percent error 35.80

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
#
# Adding residual connections improves optimization by allowing gradients to flow more easily through the network, resulting in faster convergence and lower training error.
